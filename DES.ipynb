# %% [markdown]
# <a href="https://colab.research.google.com/github/Learner-06/11239A095_DBS_Exp-s/blob/main/DES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from Crypto.Cipher import DES
from Crypto.Util.Padding import pad, unpad
from Crypto.Random import get_random_bytes
import binascii

key = get_random_bytes(8)
print("DES Symmetric key (hex):", binascii.hexlify(key).decode())

msg = input("Enter message to encrypt: ")

cipher = DES.new(key, DES.MODE_CBC)
ct_bytes = cipher.iv + cipher.encrypt(pad(msg.encode(), DES.block_size))
print("Encrypted (hex):", binascii.hexlify(ct_bytes).decode())

iv = ct_bytes[:DES.block_size]
ciphertext = ct_bytes[DES.block_size:]
decipher = DES.new(key, DES.MODE_CBC, iv)
pt = unpad(decipher.decrypt(ciphertext), DES.block_size)
print("Decrypted:", pt.decode())
# Out:
# DES Symmetric key (hex): 6c179dfd87d29296
# Enter message to encrypt: come over there
# Encrypted (hex): bf94e1570c3f126aa3bdc12ef595f8785bc09eed7abf44f5
# Decrypted: come over there

# %%
# !pip install pycryptodome
# Out:
# Collecting pycryptodome
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 32.9 MB/s eta 0:00:00
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.23.0
